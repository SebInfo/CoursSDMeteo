# %%
import pandas as pd

# %%
df = pd.read_csv("meteoMontpellier.csv", sep=";", parse_dates=["validity_time"], low_memory=False)

# %%
df.head()
# Out:
#   reference_time insert_time             validity_time      pmer   tend  \
# 0            NaN         NaN 1996-01-01 00:00:00+00:00  100230.0   70.0
# 1            NaN         NaN 1996-01-01 03:00:00+00:00  100270.0   40.0
# 2            NaN         NaN 1996-01-01 06:00:00+00:00  100090.0 -180.0
# 3            NaN         NaN 1996-01-01 09:00:00+00:00  100090.0    0.0
# 4            NaN         NaN 1996-01-01 12:00:00+00:00   99770.0 -320.0
#
#    cod_tend     dd   ff       t      td  ...  hnuage1  nnuage2  ctype2  \
# 0       0.0  240.0  5.0  282.85  279.95  ...   1380.0      NaN     NaN
# 1       2.0  220.0  3.0  282.04  279.45  ...      NaN      NaN     NaN
# 2       8.0  320.0  2.0  280.35  278.45  ...      NaN      NaN     NaN
# 3       4.0   40.0  1.0  280.54  278.85  ...      NaN      NaN     NaN
# 4       8.0   60.0  5.0  285.85  279.45  ...   3000.0      4.0     0.0
#
#    hnuage2  nnuage3  ctype3  hnuage3  nnuage4  ctype4  hnuage4
# ...

# %% [markdown]
# ## On a supprimer toutes les colonnes ne contenant que des NaN

# %%
df = df.dropna(axis=1, how="all")

# %%
df.head()
# Out:
#   reference_time insert_time             validity_time      pmer   tend  \
# 0            NaN         NaN 1996-01-01 00:00:00+00:00  100230.0   70.0
# 1            NaN         NaN 1996-01-01 03:00:00+00:00  100270.0   40.0
# 2            NaN         NaN 1996-01-01 06:00:00+00:00  100090.0 -180.0
# 3            NaN         NaN 1996-01-01 09:00:00+00:00  100090.0    0.0
# 4            NaN         NaN 1996-01-01 12:00:00+00:00   99770.0 -320.0
#
#    cod_tend     dd   ff       t      td  ...  hnuage1  nnuage2  ctype2  \
# 0       0.0  240.0  5.0  282.85  279.95  ...   1380.0      NaN     NaN
# 1       2.0  220.0  3.0  282.04  279.45  ...      NaN      NaN     NaN
# 2       8.0  320.0  2.0  280.35  278.45  ...      NaN      NaN     NaN
# 3       4.0   40.0  1.0  280.54  278.85  ...      NaN      NaN     NaN
# 4       8.0   60.0  5.0  285.85  279.45  ...   3000.0      4.0     0.0
#
#    hnuage2  nnuage3  ctype3  hnuage3  nnuage4  ctype4  hnuage4
# ...

# %%
df.shape
# Out:
# (86177, 54)

# %%
brouillard = df[df["ww"] == 10]

# %%
brouillard.shape
# Out:
# (1005, 54)

# %%
jours_brouillard = brouillard["validity_time"].dt.date.unique()

# %%
jours_brouillard
# Out:
# array([datetime.date(1996, 1, 16), datetime.date(1996, 1, 17),
#        datetime.date(1996, 2, 3), datetime.date(1996, 3, 11),
#        datetime.date(1996, 3, 21), datetime.date(1996, 3, 22),
#        datetime.date(1996, 3, 26), datetime.date(1996, 6, 9),
#        datetime.date(1996, 6, 10), datetime.date(1996, 6, 19),
#        datetime.date(1996, 7, 22), datetime.date(1996, 8, 2),
#        datetime.date(1996, 8, 7), datetime.date(1996, 9, 30),
#        datetime.date(1996, 10, 11), datetime.date(1996, 10, 12),
#        datetime.date(1996, 10, 23), datetime.date(1996, 10, 24),
#        datetime.date(1996, 10, 26), datetime.date(1996, 10, 28),
#        datetime.date(1997, 1, 3), datetime.date(1997, 1, 30),
#        datetime.date(1997, 1, 31), datetime.date(1997, 2, 1),
#        datetime.date(1997, 2, 2), datetime.date(1997, 2, 3),
#        datetime.date(1997, 2, 5), datetime.date(1997, 2, 10),
#        datetime.date(1997, 2, 11), datetime.date(1997, 2, 25),
# ...

# %%
jours_brouillard_2024 = brouillard[brouillard["validity_time"].dt.year == 2024]

# %%
jours_brouillard_2024.head
# Out:
# <bound method NDFrame.head of       reference_time insert_time             validity_time      pmer   tend  \
# 81112            NaN         NaN 2024-01-14 00:00:00+00:00  101980.0 -160.0
# 81143            NaN         NaN 2024-01-18 00:00:00+00:00   99780.0   40.0
# 81144            NaN         NaN 2024-01-18 03:00:00+00:00   99860.0   80.0
# 81233            NaN         NaN 2024-01-29 21:00:00+00:00  103450.0   70.0
# 81246            NaN         NaN 2024-01-31 18:00:00+00:00  103360.0   20.0
# 81247            NaN         NaN 2024-01-31 21:00:00+00:00  103340.0  -20.0
# 81411            NaN         NaN 2024-02-22 09:00:00+00:00  101200.0 -150.0
# 81598            NaN         NaN 2024-03-18 00:00:00+00:00  102000.0 -100.0
# 81599            NaN         NaN 2024-03-18 03:00:00+00:00  101880.0 -120.0
# 82319            NaN         NaN 2024-06-19 09:00:00+00:00  101290.0   70.0
# 82320            NaN         NaN 2024-06-19 12:00:00+00:00  101420.0  130.0
# ...

# %%
jours_brouillard_2024.shape
# Out:
# (24, 54)
