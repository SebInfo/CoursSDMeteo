# %%
from ipywidgets import IntSlider

# %%
w = IntSlider()

# %%
w
# Out:
# IntSlider(value=56)

# %%
print(w.value)
# Out:
# 15

# %%
from ipyleaflet import Map, Circle

# %%
paris=[48.866667,2.33333]

# %%
type(paris)
# Out:
# list

# %%
m=Map(center=paris, zoom=10)

# %%
m
# Out:
# Map(center=[48.866667, 2.33333], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
