# %%
from ipywidgets import IntSlider
from IPython.display import display

# %%
temp = IntSlider()

# %%
temp
# Out:
# IntSlider(value=0)

# %%
w = IntSlider(min=-10, max=20)

# %%
display (w)
# Out:
# IntSlider(value=0, max=20, min=-10)

# %%
w
# Out:
# IntSlider(value=0, max=20, min=-10)

# %%
display(w)
# Out:
# IntSlider(value=0, max=20, min=-10)
