# %%
import pandas as pd

# %%
df = pd.read_csv("meteoMontpellier.csv", sep=";")
# Out:
# /tmp/ipykernel_457277/324729540.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("meteoMontpellier.csv", sep=";")

# %%
df["validity_time"] = pd.to_datetime(df["validity_time"])

# %%
df["validity_time"].dt.year.min(), df["validity_time"].dt.year.max()
# Out:
# (np.int32(1996), np.int32(2025))

# %%
df_post_2017 = df[df["validity_time"].dt.year >= 2018]

df_post_2017["ww"].value_counts(dropna=False).head(10)
# Out:
# ww
# 0.0     21011
# 61.0      461
# 10.0      256
# 60.0      132
# NaN        86
# 63.0       85
# 45.0       70
# 44.0       46
# 58.0       34
# 51.0       27
# Name: count, dtype: int64

# %%
# !ls
# Out:
# donnees					test2Streamlit.py
# extractionVille.py			test3Streamlit.py
# meteo.csv				test4Streamlit.py
# meteoMontpellier.csv			testStreamlit.py
# pluviometrie_mensuelle_montpellier.csv	Untitled1.ipynb
# précipitation.py			Untitled.ipynb
# temperatureMontpellier.py

# %%
# !cd donnees

# %%
# !ls
# Out:
# donnees					test2Streamlit.py
# extractionVille.py			test3Streamlit.py
# meteo.csv				test4Streamlit.py
# meteoMontpellier.csv			testStreamlit.py
# pluviometrie_mensuelle_montpellier.csv	Untitled1.ipynb
# précipitation.py			Untitled.ipynb
# temperatureMontpellier.py
