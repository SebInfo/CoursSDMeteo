# %%
from ipyleaflet import Map, Circle

# %%
paris = [48.866667,2.33333]

# %%
type(paris)
# Out:
# list

# %%
carcassonne = [43.21611, 2.30833]

# %%
m=Map(center=carcassonne, zoom=15)

# %%
circle = Circle()
circle.location = carcassonne
circle.radius = 100
circle.color = "yellow"
circle.fill_color = "yellow"

# %%
m.add_layer(circle)

# %%
m
# Out:
# Map(center=[43.21611, 2.30833], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
# %whos
# Out:
# Variable      Type             Data/Info
# ----------------------------------------
# Circle        MetaHasTraits    <class 'ipyleaflet.leaflet.Circle'>
# Map           MetaHasTraits    <class 'ipyleaflet.leaflet.Map'>
# carcassonne   list             n=2
# circle        Circle           Circle(color='yellow', fi<...>', 'weight'], radius=100)
# m             Map              Map(center=[43.21611, 2.3<...>le=MapStyle(), zoom=15.0)
# paris         list             n=2

# %%
print(_i)
# Out:
# %whos

# %%
_
# Out:
# Map(center=[43.21611, 2.30833], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
# %store m
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 get_ipython().run_line_magic('store', 'm')
#
# File ~/PycharmProjects/SAEMeteo/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/PycharmProjects/SAEMeteo/.venv/lib/python3.12/site-packages/IPython/extensions/storemagic.py:229, in StoreMagics.store(self, parameter_s)
# ...

# %%
liste = [1, 2, 3]

# %%
# %store liste
# Out:
# Stored 'liste' (list)
